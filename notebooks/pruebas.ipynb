# %%
dict = {0: 'compresor1', 1: 'compresor2', 2: 'enfermeroT', 3: 'líder', 4: 'ventilador', 5: 'paciente', 6: 'UCI', 7: 'desconocido'}
lista = [6., 5., 3., 4., 4., 4.]
fieldnames = [dict[key] for key in lista]
print(fieldnames)
# Out:
# ['UCI', 'paciente', 'líder', 'ventilador', 'ventilador', 'ventilador']

# %%
classes = [dict[key] for key in dict]
print(classes)
# Out:
# ['compresor1', 'compresor2', 'enfermeroT', 'líder', 'ventilador', 'paciente', 'UCI', 'desconocido']

# %%
values = [dict[key] for key in dict]

headers = []
for value in values:
    headers.append(value+"_x1")
    headers.append(value+"_y1")
    headers.append(value+"_x2")
    headers.append(value+"_y2")

print(headers)
# Out:
# ['compresor1_x1', 'compresor1_y1', 'compresor1_x2', 'compresor1_y2', 'compresor2_x1', 'compresor2_y1', 'compresor2_x2', 'compresor2_y2', 'enfermeroT_x1', 'enfermeroT_y1', 'enfermeroT_x2', 'enfermeroT_y2', 'líder_x1', 'líder_y1', 'líder_x2', 'líder_y2', 'ventilador_x1', 'ventilador_y1', 'ventilador_x2', 'ventilador_y2', 'paciente_x1', 'paciente_y1', 'paciente_x2', 'paciente_y2', 'UCI_x1', 'UCI_y1', 'UCI_x2', 'UCI_y2', 'desconocido_x1', 'desconocido_y1', 'desconocido_x2', 'desconocido_y2']

# %%
temp_list = [None for _ in range(32)]
print(len(temp_list))
# Out:
# 32

# %%
for i, clase in enumerate(lista):

    print(i,clase)
# Out:
# 0 6.0
# 1 5.0
# 2 3.0
# 3 4.0
# 4 4.0
# 5 4.0
